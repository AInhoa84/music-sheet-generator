# %%
import librosa
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import os
from sklearn.linear_model import LinearRegression
from tqdm import tqdm_notebook as tqdm
# %matplotlib notebook

# %% [markdown]
# # Brute force linear regression

# %% [markdown]
# The idea here is to predict the note frequency of an mp3 file containing a single note using linear regression. The features will be the amplitude values of n samples (info from the time domain). Although this is technically a classification problem, it's interesting to try out this approach since the frequency is a continuous variable.

# %% [markdown]
# ## Data preprocessing (single file)

# %% [markdown]
# First we remove the samples before the note begins.

# %%
y, sr = librosa.load("../Audio_processing_tests/mp3 Notes/a3.mp3", mono=False)

# %%
y = librosa.core.to_mono(y)
# We'll work with mono here

# %%
plt.figure(figsize=(18,6))
plt.plot(y[:700])
plt.plot([0.001]*700, 'r')

# %%
y = y[np.argwhere(y >= 0.001)[0][0]:]

# %%
plt.figure(figsize=(18,6))
plt.plot(y)

# %% [markdown]
# Next we resample the waveform to reduce the number of future features

# %%
plt.figure(figsize=(18,6))
plt.plot(y[:100], 'x')
plt.plot(y[:100], '--')

# %%
y = librosa.resample(y, sr, 8000)

# %%
plt.figure(figsize=(18,6))
plt.plot(y[:round(100*8000/sr)], 'x')
plt.plot(y[:round(100*8000/sr)], '--')

# %% [markdown]
# There already seems to be a recognizable pattern at around 100 samples

# %%
plt.figure(figsize=(18,6))
plt.plot(y[250:400])

# %% [markdown]
# Now we can split the waveform into chunks of 100 samples to use them as separate examples

# %%
note_table = pd.read_csv("../Utilities/Note_table.tsv", header=0, sep="\t")
note_table.head()
# Out:
#   Note       Freq
# 0   C0  16.351598
# 1  C#0  17.323914
# 2   D0  18.354048
# 3  D#0  19.445436
# 4   E0  20.601722

# %%
note_table[note_table["Note"] == "A3"]["Freq"]
# Out:
# 45    220.0
# Name: Freq, dtype: float64

# %%
data = pd.DataFrame(columns=["x{}".format(i) for i in range(100)])

# %%
for t in range(0, len(y)-100, 100):
    y_chunk = y[t:(t+100)]
    data = data.append(pd.DataFrame({"x{}".format(i): [y_chunk[i]] for i in range(100)}))

# %%
data = data.reset_index().drop("index", axis=1)
data.head()
# Out:
#          x0        x1        x2        x3        x4        x5        x6  \
# 0  0.001025  0.001389 -0.000176 -0.000749 -0.000836  0.000455  0.000395
# 1  0.001220  0.004228  0.003287 -0.001491  0.002415  0.005526 -0.001426
# 2 -0.038639 -0.044338 -0.024061 -0.001734  0.019513  0.023870  0.016353
# 3  0.020348  0.016576  0.011641  0.000260 -0.009655 -0.010248 -0.005714
# 4  0.026487  0.024156  0.019214  0.013767  0.007092  0.000885 -0.003320
#
#          x7        x8        x9    ...          x90       x91       x92  \
# 0  0.000902 -0.000220 -0.000157    ...     0.018775  0.016326  0.013896
# 1 -0.009821 -0.002149  0.015404    ...    -0.011945 -0.018910 -0.025112
# 2  0.009345  0.008039  0.014047    ...     0.001107  0.004665  0.001738
# 3 -0.002381  0.002067  0.005329    ...     0.001002  0.001302  0.004516
# 4 -0.000217 -0.007632 -0.019659    ...    -0.047990 -0.042122 -0.027363
#
#         x93       x94       x95       x96       x97       x98       x99
# 0  0.010763  0.011352  0.010369  0.006090 -0.001213 -0.002487  0.001588
# 1 -0.030585 -0.041974 -0.041180 -0.027273 -0.009221 -0.012685 -0.025940
# 2 -0.003810 -0.007387 -0.007844 -0.003441  0.004792  0.010734  0.017967
# 3  0.011719  0.005384 -0.005421 -0.010332 -0.007485  0.001982  0.012908
# 4 -0.007935  0.005005  0.007823  0.001965  0.005932  0.015841  0.019599
#
# [5 rows x 100 columns]

# %%
plt.figure(figsize=(18,6))
row0 = data.iloc[0]
row0.index = np.arange(100)
plt.plot(row0)
row1 = data.iloc[1]
row1.index = np.arange(100, 200)
plt.plot(row1)
row2 = data.iloc[2]
row2.index = np.arange(200, 300)
plt.plot(row2)

# %%
data["Freq"] = float(note_table[note_table["Note"] == "A3"]["Freq"])

# %%
data["Freq"].head()
# Out:
# 0    220.0
# 1    220.0
# 2    220.0
# 3    220.0
# 4    220.0
# Name: Freq, dtype: float64

# %% [markdown]
# ## Data preprocessing (multiple files)

# %% [markdown]
# Now we can apply this to many files.

# %%
def file_to_data(file, rs, k, note_table):
    """
    Resample mp3 file to frequency rs, divide it into chunks of k samples and convert it
    to a dataframe
    """
    y, sr = librosa.load(file, mono=False)
    y = librosa.core.to_mono(y)
    y = y[np.argwhere(y >= 0.001)[0][0]:]
    y = librosa.resample(y, sr, rs)
    df = pd.DataFrame(columns=["x{}".format(i) for i in range(k)])
    
    for t in range(0, len(y)-k, k):
        y_chunk = y[t:(t+k)]
        df = df.append(pd.DataFrame({"x{}".format(i): [y_chunk[i]] for i in range(k)}))
        
    note_name = file.split('/')[-1].strip("mp3").strip(".").upper().replace("-", "#")
    df["Freq"] = float(note_table[note_table["Note"] == note_name]["Freq"])
    
    return df

# %% [markdown]
# Testing the function...

# %%
test = file_to_data("../Audio_processing_tests/mp3 Notes/a-3.mp3", 8000, 50, note_table)
test.head()
# Out:
#          x0        x1        x2        x3        x4        x5        x6  \
# 0  0.000993  0.000338  0.000003 -0.000528 -0.000485  0.000146  0.000654
# 0 -0.003216 -0.010109 -0.023881 -0.023509 -0.012113  0.006211  0.019842
# 0 -0.005012 -0.007586  0.006615  0.019033  0.018834  0.013232  0.002450
# 0 -0.004454 -0.006503 -0.003838  0.004022  0.017083  0.016633  0.010503
# 0  0.010826  0.002778 -0.008269 -0.007846 -0.003056  0.001883  0.004993
#
#          x7        x8        x9     ...           x41       x42       x43  \
# 0 -0.000327  0.000165  0.002672     ...      0.000060 -0.000659 -0.008528
# 0  0.015610  0.009808  0.008467     ...     -0.000434 -0.004019  0.000968
# 0  0.002638  0.004233 -0.004110     ...     -0.019637 -0.018077 -0.010877
# 0  0.011855  0.010800  0.016877     ...     -0.007764  0.016037  0.026283
# 0  0.001366 -0.005609 -0.006188     ...      0.015234  0.012832  0.011670
#
#         x44       x45       x46       x47       x48       x49        Freq
# 0 -0.013385 -0.020310 -0.024101 -0.017991 -0.012810 -0.006837  233.081881
# 0  0.000344  0.003409  0.001183 -0.002116  0.003612  0.002653  233.081881
# 0 -0.000433  0.007510  0.011413  0.007255  0.007317  0.000906  233.081881
# 0  0.017614  0.010921  0.009173  0.013912  0.010374  0.009430  233.081881
# 0  0.001714  0.000231  0.000135 -0.002761 -0.005881 -0.014175  233.081881
#
# [5 rows x 51 columns]

# %%
plt.figure(figsize=(18,6))
test = test.drop("Freq", axis=1)
row34 = test.iloc[34]
row34.index = np.arange(34*50,35*50)
plt.plot(row34)
row35 = test.iloc[35]
row35.index = np.arange(35*50, 36*50)
plt.plot(row35)
row36 = test.iloc[36]
row36.index = np.arange(36*50, 37*50)
plt.plot(row36)

# %% [markdown]
# Now for all files:

# %%
def dir_to_data(directory, rs, k, note_table):
    data = pd.DataFrame(columns=["x{}".format(i) for i in range(k)])

    for file in tqdm(os.listdir(directory)):
        df = file_to_data(directory + "/" + file, rs, k, note_table)
        data = data.append(df)
        
    data = data.reset_index().drop("index", axis=1)
    
    return data

# %%
data = dir_to_data("../Audio_processing_tests/mp3 Notes", 8000, 100, note_table)
# Out:
# HBox(children=(IntProgress(value=0, max=37), HTML(value='')))
# E:\Anaconda\lib\site-packages\pandas\core\frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
data.head()
# Out:
#          Freq        x0        x1       x10       x11       x12       x13  \
# 0  233.081881  0.000993  0.000338  0.000483 -0.001862 -0.003114  0.000844
# 1  233.081881 -0.005012 -0.007586 -0.013533 -0.015086 -0.018481 -0.028211
# 2  233.081881  0.010826  0.002778 -0.001479  0.003043  0.010486  0.018498
# 3  233.081881  0.000679 -0.000109  0.022343  0.019014  0.009870  0.009221
# 4  233.081881  0.007996  0.010096  0.007240  0.008831  0.000355 -0.006307
#
#         x14       x15       x16    ...          x90       x91       x92  \
# 0  0.004286  0.003127 -0.002322    ...     0.006825 -0.000434 -0.004019
# 1 -0.037153 -0.042907 -0.032966    ...    -0.032291 -0.007764  0.016037
# 2  0.025113  0.024818  0.017106    ...    -0.000286  0.002049  0.003968
# 3  0.002158 -0.000267  0.000701    ...    -0.015412 -0.011768 -0.017611
# 4 -0.012469 -0.013331 -0.010418    ...     0.010874 -0.001950 -0.003303
#
#         x93       x94       x95       x96       x97       x98       x99
# 0  0.000968  0.000344  0.003409  0.001183 -0.002116  0.003612  0.002653
# 1  0.026283  0.017614  0.010921  0.009173  0.013912  0.010374  0.009430
# 2  0.003444  0.005584  0.005116 -0.003299  0.001664  0.007159  0.003530
# 3 -0.032948 -0.047665 -0.037839 -0.014314  0.004501  0.010153  0.013301
# 4  0.002170  0.005139  0.000092  0.005554  0.009296  0.009130  0.003694
#
# [5 rows x 101 columns]

# %%
data.shape
# Out:
# (1822, 101)
