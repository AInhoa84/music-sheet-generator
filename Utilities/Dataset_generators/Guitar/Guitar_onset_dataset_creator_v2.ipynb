# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
from ipywidgets import interact, interactive, fixed, interact_manual, FloatSlider
from ipykernel.pylab.backend_inline import flush_figures
from IPython.display import display
import IPython as ipd
from ipywidgets import Button, jslink, Checkbox
import IPython.display as ipd
# %matplotlib inline

# %%
data = pd.DataFrame(columns=["File", "Onsets"])
onsets = []

# %%
def f(x):
    plt.figure(figsize=(18,6))
    plt.plot(y)
    plt.axvline(x=int(x), color="r")
    print(onsets)

# %%
def add_onset(onset):
    onsets.append(onset)

def add_data(vals, df, filename):
    df = pd.concat([df, pd.DataFrame({"File": [filename], "Onsets": [vals]})]).reset_index(drop=True)
    global data
    data = df.copy()
    global onsets
    onsets = []

# %%
def on_onset_button_clicked(b):
    add_onset(int(slider.value))
    
def on_data_button_clicked(b):
    add_data(onsets, data, filename)

# %%
# %run ../../Utilities.ipynb
# Out:
# Using TensorFlow backend.

# %%
import os
old = pd.read_pickle("../../../Data/Guitar/File_onset_data_corrected.pkl")
for file in os.listdir("../../../Samples/Guitar/Riffs/"):
    if file not in old["File"].values:
        print(file)
# Out:
# Guitar_noamp_riff18.mp3
# Guitar_noamp_riff18_1.mp3
# Guitar_noamp_riff18_2.mp3
# Guitar_noamp_riff18_3.mp3
# Guitar_noamp_riff18_4.mp3
# Guitar_noamp_riff18_5.mp3
# Guitar_noamp_riff18_6.mp3
# Guitar_noamp_riff18_7.mp3
# Guitar_noamp_riff19.mp3
# Guitar_noamp_riff19_1.mp3
# Guitar_noamp_riff19_2.mp3
# Guitar_noamp_riff19_3.mp3
# Guitar_noamp_riff1_7.mp3
# Guitar_noamp_riff20.mp3
# Guitar_noamp_riff20_1.mp3
# Guitar_noamp_riff20_2.mp3
# Guitar_noamp_riff20_3.mp3
# Guitar_noamp_riff20_4.mp3
# Guitar_noamp_riff21.mp3
# Guitar_noamp_riff21_1.mp3
# Guitar_noamp_riff21_2.mp3
# Guitar_noamp_riff21_3.mp3
# Guitar_noamp_riff22.mp3
# Guitar_noamp_riff22_1.mp3
# Guitar_noamp_riff22_2.mp3
# Guitar_noamp_riff22_3.mp3
# Guitar_noamp_riff28_3.mp3
# Guitar_noamp_riff28_4.mp3
# Guitar_noamp_riff28_5.mp3
# Guitar_noamp_riff29_3.mp3
# Guitar_noamp_riff2_11.mp3
# Guitar_noamp_riff2_end.mp3
# Guitar_noamp_riff30.mp3
# Guitar_noamp_riff30_3.mp3
# Guitar_noamp_riff3_8.mp3
# Guitar_noamp_riff4_2.mp3
# Guitar_noamp_riff4_3.mp3
# Guitar_noamp_riff4_4.mp3
# Guitar_noamp_riff4_5.mp3
# Guitar_noamp_riff4_6.mp3
# Guitar_noamp_riff4_7.mp3
# Guitar_noamp_riff4_8.mp3
# Guitar_noamp_riff6.mp3
# Guitar_noamp_riff8_7.mp3
# Guitar_noamp_riff8_8.mp3
# Guitar_noamp_riff9.mp3

# %%
filename = "Guitar_noamp_riff22.mp3"

# %%
y = load_file("../../../Samples/Guitar/Riffs/" + filename, 8000)

# %%
ipd.Audio(y, rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
slider = FloatSlider(min=0, max=len(y), step=50, continuous_update=False)
interact(f, x=slider)
onset_button = Button(description="Add onset")
data_button = Button(description="Add onsets to data")
display(onset_button, data_button)
onset_button.on_click(on_onset_button_clicked)
data_button.on_click(on_data_button_clicked)
# Out:
# interactive(children=(FloatSlider(value=0.0, continuous_update=False, description='x', max=15169.0, step=50.0)…
# Button(description='Add onset', style=ButtonStyle())
# Button(description='Add onsets to data', style=ButtonStyle())

# %%
data
# Out:
#                         File  \
# 0    Guitar_noamp_riff18.mp3
# 1  Guitar_noamp_riff18_1.mp3
# 2    Guitar_noamp_riff19.mp3
# 3    Guitar_noamp_riff20.mp3
# 4    Guitar_noamp_riff21.mp3
# 5    Guitar_noamp_riff22.mp3
#
#                                               Onsets
# 0  [200, 3600, 5500, 8500, 10300, 12200, 13950, 1...
# 1  [200, 3650, 5500, 8900, 10700, 12500, 14200, 1...
# 2  [150, 1900, 3450, 4950, 6650, 8100, 9600, 1130...
# 3  [150, 2200, 4450, 6600, 7450, 8600, 10700, 128...
# 4  [200, 1050, 2250, 3350, 4400, 5750, 6800, 8000...
# 5  [200, 1050, 2000, 2900, 3750, 4600, 5650, 6600...

# %%
data.to_pickle("../../../Data/Guitar/temp.pkl")

# %%
old = pd.read_pickle("../../../Data/Guitar/File_onset_data_corrected.pkl")

# %%
new = pd.concat([old, data])

# %%
new.to_pickle("../../../Data/Guitar/File_onset_data_corrected.pkl")

# %%
new.shape
# Out:
# (215, 2)
