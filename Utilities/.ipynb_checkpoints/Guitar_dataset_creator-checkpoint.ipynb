# %%
import librosa
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook as tqdm
import IPython.display as ipd

# %%
note_table = pd.read_csv("../Data/Piano/Note_table.tsv", header=0, sep="\t")

# %% [markdown]
# ## Envelope and frontier functions

# %%
ipd.Audio("../Samples/Guitar/Guitar_noamp_string1_0.mp3")
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
y, sr = librosa.load("../Samples/Guitar/Guitar_noamp_string1_0.mp3", mono=False)
y = librosa.core.to_mono(y)
y = librosa.resample(y, sr, 8000)

# %%
y.shape
# Out:
# (98497,)

# %%
plt.plot(y)

# %%
onset_frames = librosa.onset.onset_detect(y=y, sr=sr)

# %%
onset_frames = librosa.frames_to_samples(onset_frames)

# %%
def envelope(y, n):
    env_pos = []
    env_neg = []

    for i in range(0, len(y), n):
        env_pos += n * [np.max(y[i:(n+i)])]
        env_neg += n * [np.min(y[i:(n+i)])]
        
    return env_pos, env_neg

# %%
env_pos, env_neg = envelope(y[:10000], 100)

# %%
plt.figure(figsize=(18,6))
plt.plot(y[:10000])
plt.plot(env_pos, 'r')
plt.plot(env_neg, 'r')
plt.tight_layout()

# %%
a = np.array([1,20,20,1,40,1,1,2,1,1,1,10])

# %%
a[1:]
# Out:
# array([20, 20,  1, 40,  1,  1,  2,  1,  1,  1, 10])

# %%
a[:-1]
# Out:
# array([ 1, 20, 20,  1, 40,  1,  1,  2,  1,  1,  1])

# %%
b = (a[1:] >= 5*a[:-1])
f = np.argwhere(b).flatten()
f
# Out:
# array([ 0,  3, 10], dtype=int64)

# %%
f[1:]
# Out:
# array([ 3, 10], dtype=int64)

# %%
f[:-1]
# Out:
# array([0, 3], dtype=int64)

# %%
f[0]
# Out:
# 0

# %%
np.append(f[0], f[np.argwhere(f[1:] - f[:-1] > 5)+1].flatten())
# Out:
# array([ 0, 10], dtype=int64)

# %%
def frontiers(env, k):
    previous = np.array(env)[:-1]
    next = np.array(env)[1:]
    front = np.argwhere((next >= k*previous) & (next > 0.025)).flatten()
    
    selected = [front[0]]
    for i in range(1, len(front)):
        if front[i] - selected[-1] > 3600:
            selected.append(front[i])
            
    return selected

# %%
plt.figure(figsize=(18,6))
plt.plot(np.arange(f[0],f[1]), y[f[0]:f[1]])
plt.plot(np.arange(f[1],f[2]), y[f[1]:f[2]])
plt.plot(np.arange(f[2],10000), y[f[2]:10000])

# %%
plt.figure(figsize=(18,6))
plt.plot(y)
for i in range(0, len(y), 4000):
    plt.axvline(x=i, color="r")

# %% [markdown]
# ## Strings and notes

# %%
start_8 = note_table[note_table["Note"] == "E1"].index[0]
start_7 = note_table[note_table["Note"] == "B1"].index[0]
start_6 = note_table[note_table["Note"] == "E2"].index[0]
start_5 = note_table[note_table["Note"] == "A2"].index[0]
start_4 = note_table[note_table["Note"] == "D3"].index[0]
start_3 = note_table[note_table["Note"] == "G3"].index[0]
start_2 = note_table[note_table["Note"] == "B3"].index[0]
start_1 = note_table[note_table["Note"] == "E4"].index[0]

# %%
strings = {
    "8": note_table["Note"].iloc[start_8:start_8+25].values,
    "7": note_table["Note"].iloc[start_7:start_7+25].values,
    "6": note_table["Note"].iloc[start_6:start_6+25].values,
    "5": note_table["Note"].iloc[start_5:start_5+25].values,
    "4": note_table["Note"].iloc[start_4:start_4+25].values,
    "3": note_table["Note"].iloc[start_3:start_3+25].values,
    "2": note_table["Note"].iloc[start_2:start_2+25].values,
    "1": note_table["Note"].iloc[start_1:start_1+25].values
}

# %% [markdown]
# ## File processing

# %%
def file_to_data(file, rs, note_table):
    y, sr = librosa.load(file, mono=False)
    y = librosa.core.to_mono(y)
    y = librosa.resample(y, sr, rs)

    df = pd.DataFrame(columns=["x{}".format(i) for i in range(2000)]+["Note"])
    string = file.split("_")[2][-1]
    notes = strings[string]

    for i in tqdm(range(0, len(y), 4000), leave = False):
        df = df.append(pd.DataFrame({**{"x{}".format(j): y[i+j] for j in range(2000)}, 
                                    **{"Note": [notes[int(i/4000)]]}}))
    df = df.reset_index(drop=True)
    return df

# %%
test = file_to_data("../Samples/Guitar/Guitar_noamp_string1_0.mp3", 8000, note_table)
test.head()
# Out:
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
#              x0            x1            x2            x3            x4  \
# 0  6.945368e-11 -1.051609e-10  1.492790e-10 -1.997504e-10  2.528113e-10
# 1 -5.194132e-04 -4.265862e-05  5.688213e-05 -3.016007e-04 -7.923105e-04
# 2  7.212010e-04  6.729766e-04  3.130578e-03  1.737707e-03 -1.099173e-03
# 3  4.378460e-03  1.292131e-03 -2.530690e-03  7.818561e-04  2.359222e-03
# 4  1.699102e-04  9.447206e-04  1.683129e-03  1.333915e-03  1.784433e-04
#
#              x5            x6            x7            x8            x9  ...  \
# 0 -3.035270e-10  3.412894e-10 -3.564821e-10  3.358236e-10 -2.683475e-10  ...
# 1  8.443884e-04  1.323474e-03 -4.305575e-04 -2.948722e-05  6.281693e-04  ...
# 2 -2.744323e-04  2.588447e-04 -4.621796e-03 -5.271171e-03  7.177844e-04  ...
# 3 -1.750907e-03 -2.560823e-03  8.765084e-04  3.228092e-04 -1.465643e-03  ...
# 4  2.106796e-04  8.800070e-04 -1.185257e-03 -2.537834e-03 -1.532403e-03  ...
#
#       x1991     x1992     x1993     x1994     x1995     x1996     x1997  \
# 0 -0.003291  0.005425  0.012648  0.014004  0.009918 -0.001285 -0.014801
# 1 -0.027260 -0.027510 -0.008062  0.026347  0.038562  0.020287 -0.000728
# 2  0.009683 -0.000520  0.004700  0.011875  0.015170  0.001975 -0.015766
# 3  0.009442  0.003011 -0.000493 -0.025880 -0.035866 -0.020778  0.013037
# 4 -0.002909 -0.010759 -0.014436 -0.011496 -0.011694 -0.001358  0.001350
#
#       x1998     x1999  Note
# 0 -0.025146 -0.026883    E4
# 1 -0.000234  0.006060    F4
# 2 -0.022384 -0.024368   F#4
# 3  0.043745  0.039525    G4
# 4  0.001935  0.002872   G#4
#
# [5 rows x 2001 columns]

# %%
test.shape
# Out:
# (25, 2001)

# %%
plt.plot(test.drop("Note", axis=1).iloc[0].values)

# %%
librosa.output.write_wav("E4.wav", test.drop("Note", axis=1).iloc[0].values, 8000)

# %%
ipd.Audio("E4.wav")
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Multi-file processing

# %%
def dir_to_data(directory, rs, note_table):
    data = pd.DataFrame(columns=["x{}".format(i) for i in range(2000)]+["Note"])
    pbar = tqdm(os.listdir(directory))
    
    for file in pbar:
        pbar.set_description("Processing %s" % file)
        df = file_to_data(directory + file, rs, note_table)
        data = data.append(df)
        
    data = data.reset_index().drop("index", axis=1)
    return data

# %%
data = dir_to_data("../Samples/Guitar/", 8000, note_table)
# Out:
# HBox(children=(IntProgress(value=0, max=192), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))

# %%
data.shape
# Out:
# (4800, 2001)

# %%
librosa.output.write_wav("A3.wav", data[data["Note"] == "A3"].drop("Note", axis=1).sample().values.flatten(), 8000)

# %%
ipd.Audio("A3.wav")
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
data.to_pickle("../Data/Guitar/guitar-data.pkl")
